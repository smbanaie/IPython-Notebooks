# %%
import urllib2
import pandas as pd
url = "http://aima.cs.berkeley.edu/data/iris.csv"
#set1 = urllib2.Request(url)
#iris_p = urllib2.urlopen(set1)
iris_p = urllib2.urlopen(url)
iris = pd.read_csv(iris_p, sep=',', decimal='.', header=None, names= ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'])
iris.head(8)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %%
iris.columns
# Out:
# Index([u'sepal_length', u'sepal_width', u'petal_length', u'petal_width', u'target'], dtype='object')

# %%
Y=iris['target']

# %%
X = iris[['sepal_length', 'sepal_width']]
X
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# 5             5.4          3.9
# 6             4.6          3.4
# 7             5.0          3.4
# 8             4.4          2.9
# 9             4.9          3.1
# 10            5.4          3.7
# 11            4.8          3.4
# 12            4.8          3.0
# 13            4.3          3.0
# 14            5.8          4.0
# 15            5.7          4.4
# 16            5.4          3.9
# 17            5.1          3.5
# 18            5.7          3.8
# 19            5.1          3.8
# 20            5.4          3.4
# 21            5.1          3.7
# 22            4.6          3.6
# 23            5.1          3.3
# 24            4.8          3.4
# 25            5.0          3.0
# 26            5.0          3.4
# 27            5.2          3.5
# 28            5.2          3.4
# ...

# %%
print X.shape
print Y.shape
# Out:
# (150, 2)
# (150,)

# %% [markdown]
# نوع یک خروجی پاندا را از روی نحوه چاپ خروجی آن می توان حدس زد. اگر هنگام چاپ خروجی، بیشتراز یک ستون چاپ شود و نام ستونها هم بالا نوشته شود ، خروجی از نوع
# ###panda dataframe
# خواهد بود وگرنه اگر یک ستون بی نام باشد از نوع
# ###panda series
